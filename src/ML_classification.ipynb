# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path = "/content/final_diabetes_dataset_3.csv"

# %%
file_path = "/content/final_diabetes_dataset_4.csv"

# %%
file_path = "/content/final_diabetes_dataset_5.csv"

# %%
label = "Outcome"

# %%
df = pd.read_csv(file_path)

# %%
X = df.drop(columns=[label])
y = df[label]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
plt.figure(figsize=(40, 25))
plot_tree(model,
          feature_names=X.columns,
          class_names=["Non-diabetici", "Diabetici"],
          filled=True,
          rounded=True,
          fontsize=10)
plt.title("Visualizzazione dell'Albero Decisionale")
plt.show()

# %%
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.71      0.79        21
#            1       0.74      0.89      0.81        19
#
#     accuracy                           0.80        40
#    macro avg       0.81      0.80      0.80        40
# weighted avg       0.81      0.80      0.80        40

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=["Non-diabetici", "Diabetici"], yticklabels=["Non-diabetici", "Diabetici"])
plt.xlabel('Predetto')
plt.ylabel('Reale')
plt.title('Matrice di Confusione')
plt.tight_layout()
plt.show()
